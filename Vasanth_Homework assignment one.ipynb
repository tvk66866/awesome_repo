# %% [markdown]
# # Homework Assignment Number One

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import seaborn as sns
sns.set(style="ticks", color_codes=True)

# %% [markdown]
# ## Section 1: Census Data

# %% [markdown]
# Data background: https://www.kaggle.com/muonneutrino/us-census-demographic-data/data

# %%
census = pd.read_csv('../data/acs2015_county_data.csv', index_col=[0])
census.head()
# Out:
#             State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# CensusId
# 1001      Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1003      Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 1005      Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 1007      Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 1009      Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#           Native  Asian      ...       Walk  OtherTransp  WorkAtHome  \
# CensusId                     ...
# 1001         0.4    1.0      ...        0.5          1.3         1.8
# 1003         0.6    0.7      ...        1.0          1.4         3.9
# 1005         0.2    0.4      ...        1.8          1.5         1.6
# 1007         0.4    0.1      ...        0.6          1.5         0.7
# 1009         0.3    0.1      ...        0.9          0.4         2.3
#
# ...

# %%
#census.info()

# %%
# census = census.dropna()

# %%
#census.isnull().count()

# %%
#census.State.value_counts()

# %%
#census.groupby([(census['State'] =='California'),"County"])['TotalPop'].max()
#census.County[(census.State == 'California')& max(census.TotalPop)]
#census.groupby(census.State == 'Maryland') .agg(['max','min'])
# census[ 
#     #(census.State == 'Maryland') | 
#     #(census.State == 'Iowa')| 
#     (census.State == 'Oregon')] [['State','County','TotalPop']].sort_values( by = 'TotalPop',ascending = False ).head(1)

# %%
# census[(census.State == 'Iowa')][['State','County','TotalPop']].sort_values( by = 'TotalPop',ascending = False ).head(1)

# %%
# census(census.State == 'Maryland')] [['State','County','TotalPop']].sort_values( by = 'TotalPop',ascending = False ).head(1)

# %%
# census[(census.State == 'Maryland')][['State','County','TotalPop']].sort_values( by = 'TotalPop',ascending = False ).head(1)

# %%
# census.County[(census.Hispanic > census.Black)].count()

# %%
#census.count()

# %%
# census.Drive.head()
# census_donot_drive = census[(census.Donot_drive > census.Drive)]

# %%
# all_states = census.State.unique()

# %%
# all_states

# %%
# census_sub

# %%
# select_states = ['Maryland','Iowa','Oregon']
# for s in select_states:
#     print(census[(census.State == s)][['State','County','TotalPop']].sort_values( by = 'TotalPop',ascending = False ).head(1))

# %%
# type(census_sub)

# %%
#census_donot_drive.count()

# %%
# census['Donot_drive'] = census.Transit + census.Walk + census.WorkAtHome + census.Carpool

# %%
# census.Donot_drive.head()

# %%
#census[(census.State == 'Maryland')][['State','County','TotalPop']].sort_values( by = 'TotalPop',ascending = False ).head(1)

# %%
# select_states = ['New York', 'California', 'Texas', 'Pennsylvania','Ohio']
# census_sub = census[(census.State == 'New york') | (census.State == 'California') | (census.State == 'Texas') | (census.State == 'Pennsylvania') | (census.State == 'Ohio')&(census.Donot_drive > census.Drive)]
# census_sub.shape

# %%
#census_sub.head()

# %%
#census_sub.groupby('State')['County'].count()

# %%
#census.describe().T

# %%
#census.info()

# %%
sns.jointplot(x="Employed", y="Unemployment", data=census, kind="kde");

# %%
census["tot_unemp"] = census.Unemployment * census.TotalPop
census.Employed.head()
# Out:
# CensusId
# 1001    23986
# 1003    85953
# 1005     8597
# 1007     8294
# 1009    22189
# Name: Employed, dtype: int64

# %%
# census['Donot_work_home'] = 100 - census.WorkAtHome

# %%
# census.Donot_work_home.head()

# %%
# census_sub_work = census[census.WorkAtHome > 10]
# print(census_sub_work.shape)
# print(census_sub_work.head())

# %%
#census_sub_work.groupby(['State','County'])['WorkAtHome'].count()

# %%
# #import plotting library
# import matplotlib.pyplot as plt
# #Don't forget this part!
# %matplotlib inline

# %%
plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.boxplot(census.Unemployment)
plt.title('Unemployment')

plt.subplot(1, 2, 2)
plt.hist(census.Unemployment, bins = 20,
#         color = "#474350", 
#         alpha = 0.7
        )
plt.title('Unemployment, Bins = 20')


#tight_layout() adds spacing between plots
plt.tight_layout()
plt.show()

# %%
#

# %%
census_subcol = census[['State','County','TotalPop','Income','Asian','Hispanic','White','Black','Native','Pacific']]
#census_subcol.head()

# %%
census["Asian_population"] = census.TotalPop * census.Asian
# census.Asian_population.head()

# %%
census["White_population"] = census.TotalPop * census.White
# census.White_population.head()

# %%
census["Black_population"] = census.TotalPop * census.Black
# census.Black_population.head()

# %%
census["Hispanic_population"] = census.TotalPop * census.Hispanic
# census.Hispanic_population.head()

# %%
# SNS Pair plot for viewing the correllation 

sns.pairplot(census_subcol)

# %%
census.plot(kind= "scatter", x = "Asian_population", y = "Employed", c = "Income", colormap ="gist_rainbow",title = 'Asian Employed with income')
plt.tight_layout()
plt.show()

# %%
census.plot(kind= "scatter", x = "Black_population", y = "Employed", c = "Income", colormap ="gist_rainbow", title = 'Black Employed with income');

# %%
census.plot(kind= "scatter", x = "White_population", y = "Employed", c = "Income", colormap ="gist_rainbow",title = 'White Employed with income')
plt.tight_layout()
plt.show()

# %%
census.plot(kind= "scatter", x = "Hispanic_population", y = "Employed", c = "Income", colormap ="gist_rainbow",title = 'Hispanic Employed with income')

# %%
census.plot(kind= "scatter", x = "TotalPop", y = "Employed", c = "Income", colormap ="gist_rainbow",title = 'White Employed with income')
plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
plt.scatter(x = census["Asian_population"], y = census["Employed"], c = census["Income"],alpha=0.5,)
plt.title('Asian Employed and their Income scale')
plt.xlabel("Asian Population")
plt.ylabel("Employed")


plt.subplot(2,2,2)
plt.scatter( x = census.Black_population, y = census.Employed, c = census.Income,alpha=0.5)
plt.title('Black Employed and their Income scale')
plt.xlabel("Black Population")
        
plt.subplot(2,2,3)
plt.scatter(x = census.White_population, y = census.Employed, c = census.Income,alpha=0.5,)
plt.title('White Employed and their Income scale')
plt.xlabel("White Population")
plt.ylabel("Employed")

plt.subplot(2,2,4)
plt.scatter(x = census.Hispanic_population, y = census.Employed, c = census.Income,alpha=0.5,)
plt.title('Hispanic Employed and their Income scale')
plt.xlabel("Hispanic Population")

plt.tight_layout()
plt.show()

# %%
sns.scatterplot(x = census["Asian_population"], y = census["Employed"], hue = census["Income"], size = census.Asian_population, legend = False)

# %%
#

# %%
#

# %% [markdown]
# ### 1. Are there any null values? If so drop rows with nulls from your dataset

# %%
census = census.dropna()

# %% [markdown]
# ### 2. What are the most populous counties in Maryland, Iowa, and Oregon

# %%
select_states = ['Maryland','Iowa','Oregon']
for s in select_states:
    print(census[(census.State == s)][['State','County','TotalPop']].sort_values( by = 'TotalPop',ascending = False ).head(1))
# Out:
#              State      County  TotalPop
# CensusId
# 24031     Maryland  Montgomery   1017859
#          State County  TotalPop
# CensusId
# 19153     Iowa   Polk    452369
#            State     County  TotalPop
# CensusId
# 41051     Oregon  Multnomah    768418

# %% [markdown]
# ### 3. How many counties have a higher proportion of Hispanic people than black people?

# %%
census.County[(census.Hispanic > census.Black)].count()
# Out:
# 2029

# %% [markdown]
# ### 4. How many counties in New York, California, Texas, Pennsylvania, and Ohio have counties where a majority of residents do not drive to work?

# %%
census['Donot_drive'] = census.Transit + census.Walk + census.WorkAtHome + census.Carpool
census_sub = census[(census.State == 'New York') | (census.State == 'California') | (census.State == 'Texas') | (census.State == 'Pennsylvania') | (census.State == 'Ohio')&(census.Donot_drive > census.Drive)]
census_sub.groupby('State')['County'].count()
# Out:
# State
# California       58
# New York         62
# Pennsylvania     67
# Texas           253
# Name: County, dtype: int64

# %% [markdown]
# ### 5. Looking at counties where the proportion of residents who work from home is greater than 10%, do you notice any trends in the locations of those counties?

# %%
census_sub_work = census[census.WorkAtHome > 10]
census_sub_work.groupby(['State','County','PrivateWork','PublicWork'])['WorkAtHome'].count()

#ANSWER: The proportion of Private workers are relatively higher than Public workers.
# Out:
# State         County                           PrivateWork  PublicWork
# Alaska        Denali Borough                   66.4         24.5          1
#               Hoonah-Angoon Census Area        53.5         30.9          1
#               North Slope Borough              73.8         25.2          1
#               Southeast Fairbanks Census Area  64.0         27.8          1
# California    Alpine                           57.4         32.8          1
#               Lake                             66.0         22.2          1
#               Marin                            73.8         10.8          1
#               Modoc                            56.5         31.3          1
#               Mono                             62.4         25.9          1
#               Nevada                           68.1         14.7          1
#               Sierra                           45.0         42.3          1
# ...

# %% [markdown]
# ### 6.  Make a histogram and a boxplot of the Unemployment column. What do these charts tell you?

# %%
plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.boxplot(census.Unemployment)
plt.title('Unemployment')

plt.subplot(1, 2, 2)
plt.hist(census.Unemployment, bins = 20,
#         color = "#474350", 
#         alpha = 0.7
        )
plt.title('Unemployment, Bins = 20')


#tight_layout() adds spacing between plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7. Use seaborn to make four plots of your choosing on this dataset. Accompany each plot with a two-sentence description

# %%
sns.scatterplot(x = census["Asian_population"], 
                y = census["Employed"], hue = census["Income"], size = census.TotalPop)

# %%
sns.scatterplot(x = census["White_population"], y = census["Employed"], hue = census["Income"], size = census.TotalPop, )

# %%
sns.scatterplot(x = census["Black_population"], y = census["Employed"], hue = census["Income"], size = census.TotalPop, )

# %%
sns.scatterplot(x = census["Hispanic_population"], y = census["Employed"], hue = census["Income"], size = census.TotalPop, )

# %%
sns.regplot(x="Hispanic_population", y="Employed", data=census);

# %%
sns.violinplot(x=census["Poverty"])

# %% [markdown]
# ## Section 2: College Majors

# %% [markdown]
# Background: https://www.kaggle.com/roundedup/new-york-citi-bike-trip-duration/version/1

# %%
bikes = pd.read_csv('../data/citibike_feb2014.csv')
bikes.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           382  2014-02-01 00:00:00  2014-02-01 00:06:22               294
# 1           372  2014-02-01 00:00:03  2014-02-01 00:06:15               285
# 2           591  2014-02-01 00:00:09  2014-02-01 00:10:00               247
# 3           583  2014-02-01 00:00:32  2014-02-01 00:10:15               357
# 4           223  2014-02-01 00:00:41  2014-02-01 00:04:24               401
#
#         start station name  start station latitude  start station longitude  \
# 0      Washington Square E               40.730494               -73.995721
# 1       Broadway & E 14 St               40.734546               -73.990741
# 2   Perry St & Bleecker St               40.735354               -74.004831
# 3       E 11 St & Broadway               40.732618               -73.991580
# 4  Allen St & Rivington St               40.720196               -73.989978
#
# ...

# %%
#bikes.info()

# %%
#pd.to_datetime(bikes['birth year'], yearfirst = True, errors='coerce')

# %%
#bikes.gender.unique()

# %%
#bikes_sub = bikes[(bikes.tripduration > 1000) & (bikes.gender == 0)]

# %%
#bikes_sub.shape

# %% [markdown]
# ### 1. Replace the spaces in the column names with underscores

# %%
bikes.columns = bikes.columns.str.replace(' ', '_')

# %% [markdown]
# ### 2. Filter out trips that start at stations that have fewer than 1000 trips and filter out values in gender == 0

# %%
bikes_sub = bikes[(bikes.tripduration > 1000) & (bikes.gender == 0)]
bikes_sub.head()
# Out:
#      tripduration            starttime             stoptime  start_station_id  \
# 222          1277  2014-02-01 01:17:50  2014-02-01 01:39:07               469
# 266         29906  2014-02-01 01:44:59  2014-02-01 10:03:25               294
# 293          2625  2014-02-01 01:56:32  2014-02-01 02:40:17               395
# 302          2289  2014-02-01 02:01:56  2014-02-01 02:40:05               395
# 413          1467  2014-02-01 03:17:49  2014-02-01 03:42:16               304
#
#             start_station_name  start_station_latitude  \
# 222         Broadway & W 53 St               40.763441
# 266        Washington Square E               40.730494
# 293  Bond St & Schermerhorn St               40.688070
# 302  Bond St & Schermerhorn St               40.688070
# 413      Broadway & Battery Pl               40.704633
#
#      start_station_longitude  end_station_id             end_station_name  \
# 222               -73.982681             336  Sullivan St & Washington Sq
# ...

# %% [markdown]
# ### 3. Is there any sort of relationship between birthyear and tripduration?

# %%
#convert Birth Year to date format

bikes['birth_year'] = pd.to_datetime(bikes['birth_year'], yearfirst = True, errors='coerce')

# %%
#bikes.birth_year.isnull().count()
# Out:
# 224736

# %%
sns.scatterplot(x = bikes.birth_year, y = (bikes.tripduration))

# %% [markdown]
# ### 4. What are the top five most popular start and end station combinations?

# %%
bikes.sort_values(by = ['tripduration'], ascending = False)[['tripduration','start_station_name','end_station_name']].head()
# Out:
#        tripduration            start_station_name  \
# 60093        766108    S Portland Ave & Hanson Pl
# 74460        590196               1 Ave & E 18 St
# 91489        585281  MacDougal St & Washington Sq
# 85316        580700           Washington Square E
# 91100        509750            Carmine St & 6 Ave
#
#                         end_station_name
# 60093  Grand Army Plaza & Central Park S
# 74460                   W 59 St & 10 Ave
# 91489             W Broadway & Spring St
# 85316                 Broadway & E 14 St
# 91100                    9 Ave & W 22 St

# %% [markdown]
# ### 5. Use Seaborn to visualize tripduration, usertype, and gender

# %%
bikes.replace(to_replace = ['Subscriber', 'Customer'], value = [1,0], inplace = True)
bikes.usertype.unique()
# Out:
# array([1, 0])

# %%
bikes_visual = bikes[['tripduration','usertype','gender']]

# %%
#bikes_visual.info()

# %%
bikes_visual.corr()
# Out:
#               tripduration  usertype    gender
# tripduration      1.000000 -0.027808 -0.001829
# usertype         -0.027808  1.000000  0.464198
# gender           -0.001829  0.464198  1.000000

# %%
corr_df = bikes_visual.corr()
#sns.heatmap(data=corr_df)
sns.violinplot(data=corr_df, palette="Set3", bw=.2, cut=1, linewidth=1)
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 6. Which five end stations on average have the longest trips? What about shortest trips?

# %%
#

# %%
#bikes[['tripduration']].mean()

# %%
bikes.groupby(by = 'end_station_name')['tripduration'].mean().sort_values(ascending = False).head().round(1)
# Out:
# end_station_name
# 3 Ave & Schermerhorn St           3821.5
# Gallatin Pl & Livingston St       3507.7
# DeKalb Ave & Skillman St          2978.5
# Park Ave & St Edwards St          2346.4
# Metropolitan Ave & Bedford Ave    2310.3
# Name: tripduration, dtype: float64

# %%
bikes.groupby(by = 'end_station_name')['tripduration'].mean().sort_values(ascending = True).head().round(1)
# Out:
# end_station_name
# Willoughby St & Fleet St    407.9
# Monroe St & Bedford Ave     547.1
# Carlton Ave & Park Ave      554.3
# Shevchenko Pl & E 6 St      576.6
# Broadway & W 32 St          577.7
# Name: tripduration, dtype: float64

# %% [markdown]
# ### Optional

# %% [markdown]
# Use this tutorial https://www.datacamp.com/community/tutorials/time-series-analysis-tutorial to plot the number of trips by day and to show which day of the week is most popular for the bike share program

# %% [markdown]
# ## Section 3: FIFA Soccer Game data

# %% [markdown]
# Background: https://www.kaggle.com/thec03u5/fifa-18-demo-player-dataset

# %%
fifa = pd.read_csv('../data/fifa_data.csv')
fifa.head()
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#       ...      Long_Shots Curve Freekick_Accuracy Penalties  Volleys  \
# ...

# %% [markdown]
# ### 1. Clean up the dataset.
#
#     - Lowercase the column names
#     - Set the "name" column as the index
#     - Drop the following columns "national_position", "national_kit", "club_kit", "club_joining", and "contract_expiry"
#     - Get rid of all players who are goalkeepers and drop every column that starts with GK
#     - Drop every player whose rating is less than 70
#     - Convert the "height" and "weight" columns to float types
#     - Check to see if there any nulls, if so drop them from the dataset

# %%
fifa.columns = map(str.lower, fifa.columns)

# %%
#fifa.head()

# %%
fifa.set_index('name',inplace = True)

# %%
#fifa.head()

# %%
# Drop the following collumns "national_position", "national_kit", "club_kit", "club_joining", "contract_expiry"

fifa.drop(["national_position", "national_kit", "club_kit", "club_joining", "contract_expiry"],axis =1,inplace = True)

# %%
# DROP all values that are rating < 70

fifa = fifa[(fifa.rating > 70)]

# %%
# I COMMENTED TO AVOID RUNNING THIS AGAIN
fifa['height'] = (fifa['height'].str[:-2].astype(float))

# %%
fifa.height.unique()
# Out:
# array([185., 170., 174., 182., 193., 183., 195., 199., 192., 173., 180.,
#        184., 191., 176., 181., 169., 188., 187., 196., 171., 189., 190.,
#        177., 165., 186., 175., 168., 179., 163., 178., 194., 172., 167.,
#        164., 200., 198., 166., 197., 201., 161., 203., 158., 157., 162.,
#        159., 160.])

# %%
# I COMMENTED TO AVOID RUNNING THIS AGAIN
fifa['weight'] = (fifa['weight'].str[:-2].astype(float))
fifa.weight.unique()
# Out:
# array([ 80.,  72.,  68.,  85.,  92.,  82.,  79.,  74.,  95.,  91.,  90.,
#         65.,  76.,  75.,  70.,  84.,  67.,  62.,  78.,  73.,  66.,  81.,
#         87.,  89.,  60.,  83.,  71.,  88.,  86.,  94.,  63.,  77.,  61.,
#         93.,  59.,  96.,  69.,  64.,  98.,  58.,  57.,  97.,  56., 102.,
#         99., 100.])

# %%
#fifa.nationality.unique()

# %%
#fifa[(fifa.nationality == 'France') & (fifa.preffered_foot == 'Left')]['height'].sort_values(ascending = False).head(1)
# Out:
# name
# Thomas Didillon    193.0
# Name: height, dtype: float64

# %%
#fifa.info()

# %% [markdown]
# ### 2.  Who are the top five players of the following attributes: speed, marking, and finishing

# %%
fifa.sort_values(by = ['speed'],ascending = False)[['speed']].head()
# Out:
#                            speed
# name
# Pierre-Emerick Aubameyang     96
# Jonathan Biabiany             96
# Víctor Ibarbo                 95
# Jürgen Damm                   95
# Williams                      95

# %%
fifa.sort_values(by = ['marking'],ascending = False)[['marking']].head()
# Out:
#                    marking
# name
# Giorgio Chiellini       92
# Andrea Barzagli         90
# Jérôme Boateng          90
# Thiago Silva            90
# Miranda                 89

# %%
fifa.sort_values(by = ['finishing'],ascending = False)[['finishing']].head()
# Out:
#                     finishing
# name
# Lionel Messi               95
# Luis Suárez                94
# Cristiano Ronaldo          93
# Gonzalo Higuaín            92
# Robert Lewandowski         91

# %% [markdown]
# ### 3. Who is the tallest French lefted foot player?

# %%
fifa[(fifa.nationality == 'France') & (fifa.preffered_foot == 'Left')]['height'].sort_values(ascending = False).head(1)
# Out:
# name
# Thomas Didillon    193.0
# Name: height, dtype: float64

# %% [markdown]
# ### 4. Show a pandas series of every attribute's correlation with the rating attribute

# %%
corr_f = fifa.corr()
fifa.corr().rating
# Out:
# rating                1.000000
# height                0.062002
# weight                0.070265
# age                   0.032832
# weak_foot             0.119383
# skill_moves           0.129214
# ball_control          0.160762
# dribbling             0.129167
# marking               0.014391
# sliding_tackle        0.037831
# standing_tackle       0.046609
# aggression            0.066394
# reactions             0.676155
# attacking_position    0.119444
# interceptions         0.066953
# vision                0.251631
# composure             0.340877
# crossing              0.105331
# short_pass            0.195568
# long_pass             0.185666
# acceleration          0.087132
# speed                 0.092125
# stamina               0.079008
# strength              0.089955
# balance               0.041867
# agility               0.107170
# jumping               0.097195
# heading               0.070283
# shot_power            0.129757
# finishing             0.131914
# ...

# %% [markdown]
# ### 5. Make a heatmap of the dataset's correlation table

# %%
sns.heatmap(corr_f)

# %% [markdown]
# ### 6. Return a dataframe with only players from the following clubs. Call the dataframe fifa2. From now on we'll be using fifa2

# %%
clubs_list = ['Real Madrid', 'FC Barcelona', 'FC Bayern', 'Manchester Utd',
       'Chelsea', 'Arsenal', 'Juventus', 'PSG', 'Manchester City',
              'Bor. Dortmund', 'Liverpool', 'Roma']

# %%
# df['equal_or_lower_than_4?'] = df['set_of_numbers'].apply(lambda x: 'True' if x <= 4 else 'False')
fifa['club_list'] = fifa.club.apply(lambda x: 'True' if x in clubs_list else 'False')
fifa.club_list.unique()
# Out:
# array(['True', 'False'], dtype=object)

# %%
fifa2 = fifa[(fifa.club_list == 'True')]

# %%
#fifa2.shape
# Out:
# (270, 48)

# %%
#fifa2.club.unique()
# Out:
# array(['Real Madrid', 'FC Barcelona', 'FC Bayern', 'Manchester Utd',
#        'Chelsea', 'Arsenal', 'Juventus', 'PSG', 'Manchester City',
#        'Bor. Dortmund', 'Liverpool', 'Roma'], dtype=object)

# %% [markdown]
# ### 7. Make a bar plot of the average long_shots, curve, and dribbling attributes of the clubs in the data

# %%
sns.barplot(data = fifa2.groupby(by= 'club')['long_shots','curve','dribbling'].mean())
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 8. Make a scatter plot of short_pass vs marking and use the preffered_foot column to color-encode the dots.

# %%
sns.scatterplot(x = fifa2.short_pass, y = fifa2.marking, hue = fifa2.preffered_foot)

# %% [markdown]
# ### 9. Make a grouped boxplots using club_position as the x axis for the following attributes: dribbling, balance, and sliding_tackle

# %%
#Dribbling boxplot

# %% [markdown]
# Which position is better at dribbling? ST or RCM? Why?

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.boxplot(ax = ax, x = fifa2.club_position, y = fifa2.dribbling)

#ANSWER: ST is better as the variation is less and is more consistent.

# %%
#Balance boxplot

# %% [markdown]
# Which position is better at balance? LM or LDM? Why?

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.boxplot(ax = ax, x = fifa2.club_position, y = fifa2.balance)

#ANSWER: LDM is better as it has relatively less variation

# %%
#sliding_tackle boxplot

# %% [markdown]
# What is the IQR for positions ST, RB, and RM?

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.boxplot(ax = ax, x = fifa2.club_position, y = fifa2.sliding_tackle)

# %%
#IQR Calculation
from scipy.stats import iqr

# %%
x = fifa2[(fifa2.club_position =='ST')]['sliding_tackle']
print("ST Club position IQR for Sliding tackle : ", iqr(x))
# Out:
# ST Club position IQR for Sliding tackle :  17.75

# %%
x = fifa2[(fifa2.club_position =='RB')]['sliding_tackle']
print("RB Club position IQR for Sliding tackle : ", iqr(x))
# Out:
# RB Club position IQR for Sliding tackle :  6.75

# %%
x = fifa2[(fifa2.club_position =='RM')]['sliding_tackle']
print("RM Club position IQR for Sliding tackle : ", iqr(x))
# Out:
# RM Club position IQR for Sliding tackle :  31.75
